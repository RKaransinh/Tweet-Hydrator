# %%
from google.colab import drive
import pandas as p
import numpy as n
from google.colab import files
drive.mount('/content/drive')

# %%
tweetIds=p.DataFrame(p.read_csv("LOCAITON OF CSV FILE ON THE DRIVE",names=['tweet_ID','Sentiment_Score']))

# %%
OnlyIds=tweetIds.drop(columns=['Sentiment_Score'])

# %%
n.savetxt('LOCAITON TO SAVE TXT FILE ON THE DRIVE/OnlyIds.txt', OnlyIds.values, fmt='%d')

# %%
files.download('OnlyIds.txt')
